# %%
# AI Research Assistant – Working Gemini Code

from google import genai
from transformers import AutoTokenizer
from google.colab import userdata
from google import genai

# %%
api_key = userdata.get("api")
client = genai.Client(api_key=api_key)

# %%
model_name = "gemini-2.5-flash"

# %% [markdown]
# # TASK 1 – LLM Interaction

# %%
print("\n            TASK 1 : LLM INTERACTION            \n")

article = """
Artificial Intelligence is transforming modern education. AI-powered tools
enable personalized learning experiences by analyzing student performance
data and adapting teaching methods accordingly. Universities are adopting
AI systems to automate administrative tasks, detect plagiarism, and provide
intelligent tutoring systems. However, concerns regarding data privacy,
ethical usage, and over-reliance on automation remain significant challenges.
Experts believe AI will support educators rather than replace them.
"""

response = client.models.generate_content(
    model=model_name,
    contents=f"Summarize the following article:\n{article}"
)

print("Summary:\n")
print(response.text)
# Out:
#             TASK 1 : LLM INTERACTION
#
# Summary:
#
# Artificial intelligence is revolutionizing modern education by providing personalized learning experiences through data analysis and adaptive teaching. Universities are implementing AI for administrative automation, plagiarism detection, and intelligent tutoring systems. However, the technology faces significant challenges related to data privacy, ethical use, and potential over-reliance on automation. Experts believe AI will primarily support educators, not replace them.

# %% [markdown]
# # TASK 2 – Prompt Engineering

# %%
print("\n            TASK 2 : PROMPT ENGINEERING               \n")

zero_prompt = f"""
Summarize the following article in 5 bullet points:

{article}
"""

response = client.models.generate_content(
    model=model_name,
    contents=zero_prompt
)

print("Zero Shot Output:\n")
print(response.text)
# Out:
#             TASK 2 : PROMPT ENGINEERING
#
# Zero Shot Output:
#
# Here's a summary of the article in 5 bullet points:
#
# *   Artificial Intelligence is revolutionizing modern education.
# *   AI tools enable personalized learning by analyzing student data and adapting teaching methods.
# *   Universities are implementing AI for administrative automation, plagiarism detection, and intelligent tutoring.
# *   Key challenges include data privacy concerns, ethical usage, and potential over-reliance on automation.
# *   Experts anticipate AI will support and enhance educators' roles rather than replace them.

# %% [markdown]
# # TASK 3 – Prompt Optimization

# %%
print("\n                TASK 3 : PROMPT OPTIMIZATION              \n")

optimized_prompt = f"""
You are an academic research assistant.

Provide:
3 Key Insights
1 Actionable Recommendation

Article:
{article}
"""

response = client.models.generate_content(
    model=model_name,
    contents=optimized_prompt
)

print(response.text)
# Out:
#                 TASK 3 : PROMPT OPTIMIZATION
#
# Here are 3 Key Insights and 1 Actionable Recommendation based on the provided article:
#
# ---
#
# ### 3 Key Insights:
#
# 1.  **AI is a Multifaceted Enabler of Educational Transformation:** AI's impact extends beyond direct learning, encompassing personalized student experiences through data analysis, administrative automation, academic integrity (plagiarism detection), and intelligent tutoring systems, thereby streamlining various facets of the educational ecosystem.
# 2.  **Personalized Learning is AI's Core Pedagogical Contribution:** A central theme is AI's ability to analyze student performance data and adapt teaching methods, fundamentally enabling tailored, adaptive learning experiences that cater to individual student needs and learning paces.
# 3.  **Ethical and Practical Challenges Coexist with Benefits:** Despite its transformative potential, the widespread adoption of AI in education is significantly challenged by critical concerns surrounding data privacy, the ethical implications of its usage, and the risks associated with an over-reliance on automated systems.
#
# ### 1 Actionable Recommendation:
#
# **Develop and Implement Comprehensive AI Governance Frameworks:** Educational institutions should proactively establish robust governance frameworks that outline clear policies and best practices for AI integration. These frameworks must prioritize data privacy protocols, mandate ethical guidelines for AI tool deployment, and emphasize the design and utilization of AI systems to *augment* educators' capabilities rather than automate or replace their core pedagogical roles.

# %% [markdown]
# # TASK 4 – Tokenization

# %%
print("\n                 TASK 4 : TOKENIZATION                  \n")

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Artificial intelligence is transforming education systems worldwide."

tokens = tokenizer.tokenize(text)

print("Tokens:", tokens)
print("Token Count:", len(tokens))
# Out:
#                  TASK 4 : TOKENIZATION
#
# Tokens: ['artificial', 'intelligence', 'is', 'transforming', 'education', 'systems', 'worldwide', '.']
# Token Count: 8

# %% [markdown]
# # TASK 5 – Mini AI Tool

# %%
print("\n              TASK 5 : MINI AI ASSISTANT                  \n")

user_article = input("Enter a research article:\n")

prompt = f"""
Generate:

1. Short Summary
2. Three Key Insights
3. One Actionable Recommendation

Article:
{user_article}
"""

response = client.models.generate_content(
    model=model_name,
    contents=prompt
)

print("\nAI Assistant Output:\n")
print(response.text)
# Out:
#               TASK 5 : MINI AI ASSISTANT
#
# Enter a research article:
# Impact of Ai in Normal Life of a Human?
#
# AI Assistant Output:
#
# Given the article title "Impact of Ai in Normal Life of a Human?", here's a summary, key insights, and an actionable recommendation:
#
# ---
#
# ### 1. Short Summary
#
# The article likely explores the pervasive and often subtle integration of Artificial Intelligence into everyday human life. It details how AI technologies, from personalized recommendations and voice assistants to automated tasks and smart devices, are reshaping how we work, communicate, learn, and make decisions. The discussion encompasses both the significant conveniences and efficiencies AI brings, as well as emerging challenges related to privacy, algorithmic bias, and the transformation of human interaction.
#
# ---
#
# ### 2. Three Key Insights
#
# 1.  **AI's Ubiquitous, Often Invisible Integration:** AI is no longer a futuristic concept but is deeply woven into the fabric of daily life, often operating in the background through smartphones, smart homes, personalized online experiences, and digital services, making its presence both pervasive and frequently unnoticed.
# 2.  **The Dual Edge of Convenience and Concern:** While AI significantly enhances convenience, efficiency, and access to information (e.g., navigation, predictive text, automated customer service), it simultaneously introduces complex challenges related to data privacy, algorithmic bias, potential job displacement, and subtle impacts on critical thinking and human connection.
# 3.  **The Imperative for Human Adaptation and Literacy:** To effectively navigate an AI-infused world, individuals must develop a greater understanding of how AI works, its limitations, and its ethical implications. This literacy is crucial for making informed choices, mitigating risks, and leveraging AI's benefits responsibly in personal and professional spheres.
#
# ---
#
# ### 3. One Actionable Recommendation
#
# **Cultivate AI Literacy and Critical Engagement:** Actively seek to understand how the AI tools you use daily (e.g., social media algorithms, voice assistants, recommendation engines) function, what data they collect, and their potential biases. Regularly question the information and suggestions AI presents, and consciously evaluate its influence on your decisions and interactions to maintain agency in an AI-driven world.
